# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
sales = pd.read_csv("Advertising.csv")
print(sales.head())
# Out:
#    no.     TV  Radio  Newspaper  Sales
# 0    1  230.1   37.8       69.2   22.1
# 1    2   44.5   39.3       45.1   10.4
# 2    3   17.2   45.9       69.3    9.3
# 3    4  151.5   41.3       58.5   18.5
# 4    5  180.8   10.8       58.4   12.9

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(12, 10))
sns.heatmap(sales.corr())
plt.show()

# %%
sales.shape
# Out:
# (200, 5)

# %%
print(data.isnull().sum())
# Out:
# no.          0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x = np.array(data.drop(["Sales"], 1))
y = np.array(data["Sales"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

data = pd.DataFrame(data={"Predicted Sales": ypred.flatten()})
print(data)
# Out:
#     Predicted Sales
# 0         16.412277
# 1         20.843193
# 2         21.511869
# 3         10.653100
# 4         22.124058
# 5         13.123835
# 6         21.037489
# 7          7.503854
# 8         13.647870
# 9         15.120409
# 10         9.020556
# 11         6.706666
# 12        14.401551
# 13         8.886090
# 14         9.743533
# 15        12.215520
# 16         8.713709
# 17        16.294145
# 18        10.268023
# 19        18.804982
# 20        19.588647
# 21        13.223183
# 22        12.364787
# 23        21.314736
# 24         7.797347
# 25         5.781900
# 26        20.749348
# 27        11.954767
# 28         9.199109
# 29         8.521787
# 30        12.404313
# 31         9.948652
# 32        21.368803
# 33        12.253748
# 34        18.299435
# 35        20.133474
# 36        14.074646
# 37        20.885947
# 38        11.052150
# 39         4.551687
# C:\Users\HP\AppData\Local\Temp\ipykernel_11060\607162594.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(data.drop(["Sales"], 1))

# %%
sns.pairplot(sales, kind="reg",corner=True, );

# %%
X=sales.iloc[:,:-1]
y=sales.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.2, random_state=45)
print("Shape of X_train", X_train.shape)
print("Shape of y_train", y_train.shape)
# Out:
# Shape of X_train (160, 4)
# Shape of y_train (160,)

# %%
mul_reg= LinearRegression()
mul_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = mul_reg.predict(X_test)

# %%
compare= pd.DataFrame({"y_test":list(y_test), "pred":list(pred)})
compare.head()
# Out:
#    y_test       pred
# 0    14.9  15.304751
# 1     8.8  10.248574
# 2    16.6  16.568926
# 3    23.8  21.879357
# 4    12.0  16.076553

# %%
plt.scatter(y_test, pred)

# %%
from sklearn import metrics

MAE = metrics.mean_absolute_error(y_test, pred)
print("Mean Absolute error:{}".format(MAE))

MSE = metrics.mean_squared_error(y_test, pred)
print('Mean Squared error: {}'.format(np.sqrt(MSE)))

R2 = metrics.r2_score(y_test, pred)
print("R2 Score:{}".format(R2))
# Out:
# Mean Absolute error:1.104032093638534
# Mean Squared error: 1.531065774743485
# R2 Score:0.8915316806090339
